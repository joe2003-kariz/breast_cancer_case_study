# %% [markdown]
# # Step 2: Data Understanding & Exploratory Data Analysis (EDA)
# This notebook focuses on understanding the structure, quality, and relationships within the breast cancer dataset provided for the case study project. We will examine data types, missing values, feature distributions, correlations, and potential outliers to prepare for the modeling phase.

# %%
# Install Required Libraries
# !pip install pandas numpy matplotlib seaborn --quiet

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set display and style
sns.set(style='whitegrid')
# %matplotlib inline

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('Data for Task 1.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ## Basic Information About the Dataset

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %% [markdown]
# ## Check for Missing Values

# %%
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %% [markdown]
# ## Drop Unnecessary Columns

# %%
# Drop ID and empty column
if 'Unnamed: 32' in df.columns:
    df.drop(columns=['id', 'Unnamed: 32'], inplace=True)
else:
    df.drop(columns=['id'], inplace=True)

# %% [markdown]
# ## Encode Target Variable ('diagnosis')

# %%
df['diagnosis'] = df['diagnosis'].map({'M': 1, 'B': 0})

# %% [markdown]
# ## Class Distribution

# %%
sns.countplot(x='diagnosis', data=df)
plt.title('Distribution of Malignant and Benign Cases')
plt.xticks([0, 1], ['Benign', 'Malignant'])
plt.show()

# %% [markdown]
# ## Feature Correlation Matrix

# %%
plt.figure(figsize=(16, 12))
sns.heatmap(df.corr(), cmap='coolwarm', annot=False, linewidths=0.5)
plt.title('Feature Correlation Matrix')
plt.show()

# %% [markdown]
# ## Pairplot of Selected Features

# %%
selected_features = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean', 'diagnosis']
sns.pairplot(df[selected_features], hue='diagnosis', palette='husl')
plt.show()
